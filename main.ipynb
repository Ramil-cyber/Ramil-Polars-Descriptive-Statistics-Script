# %%
import main

# %%
df = main.read_csv("Health_Sleep_Statistics.csv")

# %% [markdown]
# ## Descriptive Statistics

# %%
df.head()
# Out:
# shape: (5, 12)
# ┌─────────┬─────┬────────┬─────────┬───┬──────────┬───────────┬─────────────────┬────────────┐
# │ User ID ┆ Age ┆ Gender ┆ Sleep   ┆ … ┆ Physical ┆ Dietary   ┆ Sleep Disorders ┆ Medication │
# │ ---     ┆ --- ┆ ---    ┆ Quality ┆   ┆ Activity ┆ Habits    ┆ ---             ┆ Usage      │
# │ i64     ┆ i64 ┆ str    ┆ ---     ┆   ┆ Level    ┆ ---       ┆ str             ┆ ---        │
# │         ┆     ┆        ┆ i64     ┆   ┆ ---      ┆ str       ┆                 ┆ str        │
# │         ┆     ┆        ┆         ┆   ┆ str      ┆           ┆                 ┆            │
# ╞═════════╪═════╪════════╪═════════╪═══╪══════════╪═══════════╪═════════════════╪════════════╡
# │ 1       ┆ 25  ┆ f      ┆ 8       ┆ … ┆ medium   ┆ healthy   ┆ no              ┆ no         │
# │ 2       ┆ 34  ┆ m      ┆ 7       ┆ … ┆ low      ┆ unhealthy ┆ yes             ┆ yes        │
# │ 3       ┆ 29  ┆ f      ┆ 9       ┆ … ┆ high     ┆ healthy   ┆ no              ┆ no         │
# ...

# %% [markdown]
# ## Summary Statistics

# %%
stats = main.get_descriptive_stats(df)
stats
# Out:
# shape: (9, 13)
# ┌────────────┬───────────┬──────────┬────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ statistic  ┆ User ID   ┆ Age      ┆ Gender ┆ … ┆ Physical   ┆ Dietary    ┆ Sleep     ┆ Medicatio │
# │ ---        ┆ ---       ┆ ---      ┆ ---    ┆   ┆ Activity   ┆ Habits     ┆ Disorders ┆ n Usage   │
# │ str        ┆ f64       ┆ f64      ┆ str    ┆   ┆ Level      ┆ ---        ┆ ---       ┆ ---       │
# │            ┆           ┆          ┆        ┆   ┆ ---        ┆ str        ┆ str       ┆ str       │
# │            ┆           ┆          ┆        ┆   ┆ str        ┆            ┆           ┆           │
# ╞════════════╪═══════════╪══════════╪════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ count      ┆ 100.0     ┆ 100.0    ┆ 100    ┆ … ┆ 100        ┆ 100        ┆ 100       ┆ 100       │
# │ null_count ┆ 0.0       ┆ 0.0      ┆ 0      ┆ … ┆ 0          ┆ 0          ┆ 0         ┆ 0         │
# ...

# %% [markdown]
# ## Visualization

# %%
main.get_histogram(df, "Age")
# Out:
# True

# %%
main.get_line_graph(dataframe =  df, x_col =  'Daily Steps', y_col = 'Calories Burned' )
# Out:
# True
